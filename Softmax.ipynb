# %% [markdown]
# <a href="https://colab.research.google.com/github/GandhamCharanSai/FML/blob/main/Softmax.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def softmax(x):
  return np.exp(x)/np.sum(np.exp(x),axis=0)

# %%
x=np.linspace(-10,10)
plt.plot(x,softmax(x))
plt.axis('tight')
plt.title('Activation Function : SOFTMAX')
plt.show()
